# %%
import glob, os
import pydicom
import matplotlib.pyplot as plt
import numpy as np

# %%
file_names = []
for file in os.listdir("./alignment_images"):
    if file.endswith(".dcm"):
        file_name = os.path.join("./alignment_images/", file[:])
        print(file_name)
        file_names.append(file_name)
# Out:
# ./alignment_images/IM-0002-0001.dcm
# ./alignment_images/IM-0002-0002.dcm
# ./alignment_images/IM-0002-0003.dcm
# ./alignment_images/IM-0002-0004.dcm
# ./alignment_images/IM-0002-0005.dcm
# ./alignment_images/IM-0002-0006.dcm
# ./alignment_images/IM-0002-0007.dcm
# ./alignment_images/IM-0002-0008.dcm
# ./alignment_images/IM-0002-0009.dcm
# ./alignment_images/IM-0002-0010.dcm
# ./alignment_images/IM-0002-0011.dcm
# ./alignment_images/IM-0002-0012.dcm
# ./alignment_images/IM-0002-0013.dcm
# ./alignment_images/IM-0002-0014.dcm
# ./alignment_images/IM-0002-0015.dcm
# ./alignment_images/IM-0002-0016.dcm
# ./alignment_images/IM-0002-0017.dcm
# ./alignment_images/IM-0002-0018.dcm
# ./alignment_images/IM-0002-0019.dcm
# ./alignment_images/IM-0002-0020.dcm
# ./alignment_images/IM-0002-0021.dcm
# ./alignment_images/IM-0002-0022.dcm
# ./alignment_images/IM-0002-0023.dcm
# ./alignment_images/IM-0002-0024.dcm
# ./alignment_images/IM-0002-0025.dcm
# ./alignment_images/IM-0002-0026.dcm
# ./alignment_images/IM-0002-0027.dcm
# ./alignment_images/IM-0002-0028.dcm
# ./alignment_images/IM-0002-0029.dcm
# ./alignment_images/IM-0002-0030.dcm
# ./alignment_images/IM-0002-0031.dcm
# ./alignment_images/IM-0002-0032.dcm
# ./alignment_images/IM-0002-0033.dcm
# ./alignment_images/IM-0002-0034.dcm
# ./alignment_images/IM-0002-0035.dcm
# ./alignment_images/IM-0002-0036.dcm
# ./alignment_images/IM-0002-0037.dcm
# ./alignment_images/IM-0002-0038.dcm
# ./alignment_images/IM-0002-0039.dcm
# ./alignment_images/IM-0002-0040.dcm
# ./alignment_images/IM-0002-0041.dcm
# ./alignment_images/IM-0002-0042.dcm
# ./alignment_images/IM-0002-0043.dcm
# ./alignment_images/IM-0002-0044.dcm
# ./alignment_images/IM-0002-0045.dcm
# ./alignment_images/IM-0002-0046.dcm
# ./alignment_images/IM-0002-0047.dcm
# ./alignment_images/IM-0002-0048.dcm
# ./alignment_images/IM-0002-0049.dcm
# ./alignment_images/IM-0002-0050.dcm
# ./alignment_images/IM-0002-0051.dcm
# ./alignment_images/IM-0002-0052.dcm
# ./alignment_images/IM-0002-0053.dcm
# ./alignment_images/IM-0002-0054.dcm
# ./alignment_images/IM-0002-0055.dcm
# ./alignment_images/IM-0002-0056.dcm
# ./alignment_images/IM-0002-0057.dcm
# ./alignment_images/IM-0002-0058.dcm
# ./alignment_images/IM-0002-0059.dcm
# ./alignment_images/IM-0002-0060.dcm
# ./alignment_images/IM-0002-0061.dcm
# ./alignment_images/IM-0002-0062.dcm
# ./alignment_images/IM-0002-0063.dcm
# ./alignment_images/IM-0002-0064.dcm
# ./alignment_images/IM-0002-0065.dcm
# ./alignment_images/IM-0002-0066.dcm
# ./alignment_images/IM-0002-0067.dcm
# ./alignment_images/IM-0002-0068.dcm
# ./alignment_images/IM-0002-0069.dcm
# ./alignment_images/IM-0002-0070.dcm
# ./alignment_images/IM-0002-0071.dcm
# ./alignment_images/IM-0002-0072.dcm
# ./alignment_images/IM-0002-0073.dcm
# ./alignment_images/IM-0002-0074.dcm
# ./alignment_images/IM-0002-0075.dcm
# ./alignment_images/IM-0002-0076.dcm
# ./alignment_images/IM-0002-0077.dcm
# ./alignment_images/IM-0002-0078.dcm
# ./alignment_images/IM-0002-0079.dcm
# ./alignment_images/IM-0002-0080.dcm
# ./alignment_images/IM-0002-0081.dcm
# ./alignment_images/IM-0002-0082.dcm
# ./alignment_images/IM-0002-0083.dcm
# ./alignment_images/IM-0002-0084.dcm
# ./alignment_images/IM-0002-0085.dcm
# ./alignment_images/IM-0002-0086.dcm
# ./alignment_images/IM-0002-0087.dcm
# ./alignment_images/IM-0002-0088.dcm
# ./alignment_images/IM-0002-0089.dcm
# ./alignment_images/IM-0002-0090.dcm
# ./alignment_images/IM-0002-0091.dcm
# ./alignment_images/IM-0002-0092.dcm
# ./alignment_images/IM-0002-0093.dcm
# ./alignment_images/IM-0002-0094.dcm
# ./alignment_images/IM-0002-0095.dcm
# ./alignment_images/IM-0002-0096.dcm
# ./alignment_images/IM-0002-0097.dcm
# ./alignment_images/IM-0002-0098.dcm
# ./alignment_images/IM-0002-0099.dcm
# ./alignment_images/IM-0002-0100.dcm
# ./alignment_images/IM-0002-0101.dcm
# ./alignment_images/IM-0002-0102.dcm
# ./alignment_images/IM-0002-0103.dcm
# ./alignment_images/IM-0002-0104.dcm
# ./alignment_images/IM-0002-0105.dcm
# ./alignment_images/IM-0002-0106.dcm
# ./alignment_images/IM-0002-0107.dcm
# ./alignment_images/IM-0002-0108.dcm
# ./alignment_images/IM-0002-0109.dcm
# ./alignment_images/IM-0002-0110.dcm
# ./alignment_images/IM-0002-0111.dcm
# ./alignment_images/IM-0002-0112.dcm
# ./alignment_images/IM-0002-0113.dcm
# ./alignment_images/IM-0002-0114.dcm
# ./alignment_images/IM-0002-0115.dcm
# ./alignment_images/IM-0002-0116.dcm
# ./alignment_images/IM-0002-0117.dcm
# ./alignment_images/IM-0002-0118.dcm
# ./alignment_images/IM-0002-0119.dcm
# ./alignment_images/IM-0002-0120.dcm
# ./alignment_images/IM-0002-0121.dcm
# ./alignment_images/IM-0002-0122.dcm
# ./alignment_images/IM-0002-0123.dcm
# ./alignment_images/IM-0002-0124.dcm
# ./alignment_images/IM-0002-0125.dcm
# ./alignment_images/IM-0002-0126.dcm
# ./alignment_images/IM-0002-0127.dcm
# ./alignment_images/IM-0002-0128.dcm
# ./alignment_images/IM-0002-0129.dcm
# ./alignment_images/IM-0002-0130.dcm
# ./alignment_images/IM-0002-0131.dcm
# ./alignment_images/IM-0002-0132.dcm
# ./alignment_images/IM-0002-0133.dcm
# ./alignment_images/IM-0002-0134.dcm
# ./alignment_images/IM-0002-0135.dcm
# ./alignment_images/IM-0002-0136.dcm
# ./alignment_images/IM-0002-0137.dcm
# ./alignment_images/IM-0002-0138.dcm
# ./alignment_images/IM-0002-0139.dcm
# ./alignment_images/IM-0002-0140.dcm
# ./alignment_images/IM-0002-0141.dcm
# ./alignment_images/IM-0002-0142.dcm
# ./alignment_images/IM-0002-0143.dcm
# ./alignment_images/IM-0002-0144.dcm
# ./alignment_images/IM-0002-0145.dcm
# ./alignment_images/IM-0002-0146.dcm
# ./alignment_images/IM-0002-0147.dcm
# ./alignment_images/IM-0002-0148.dcm
# ./alignment_images/IM-0002-0149.dcm
# ./alignment_images/IM-0002-0150.dcm
# ./alignment_images/IM-0002-0151.dcm
# ./alignment_images/IM-0002-0152.dcm
# ./alignment_images/IM-0002-0153.dcm
# ./alignment_images/IM-0002-0154.dcm
# ./alignment_images/IM-0002-0155.dcm
# ./alignment_images/IM-0002-0156.dcm
# ./alignment_images/IM-0002-0157.dcm
# ./alignment_images/IM-0002-0158.dcm
# ./alignment_images/IM-0002-0159.dcm
# ./alignment_images/IM-0002-0160.dcm
# ./alignment_images/IM-0002-0161.dcm
# ./alignment_images/IM-0002-0162.dcm
# ./alignment_images/IM-0002-0163.dcm
# ./alignment_images/IM-0002-0164.dcm
# ./alignment_images/IM-0002-0165.dcm
# ./alignment_images/IM-0002-0166.dcm
# ./alignment_images/IM-0002-0167.dcm
# ./alignment_images/IM-0002-0168.dcm
# ./alignment_images/IM-0002-0169.dcm
# ./alignment_images/IM-0002-0170.dcm
# ./alignment_images/IM-0002-0171.dcm
# ./alignment_images/IM-0002-0172.dcm
# ./alignment_images/IM-0002-0173.dcm
# ./alignment_images/IM-0002-0174.dcm
# ./alignment_images/IM-0002-0175.dcm
# ./alignment_images/IM-0002-0176.dcm
# ./alignment_images/IM-0002-0177.dcm
# ./alignment_images/IM-0002-0178.dcm
# ./alignment_images/IM-0002-0179.dcm
# ./alignment_images/IM-0002-0180.dcm
# ./alignment_images/IM-0002-0181.dcm
# ./alignment_images/IM-0002-0182.dcm
# ./alignment_images/IM-0002-0183.dcm
# ./alignment_images/IM-0002-0184.dcm
# ./alignment_images/IM-0002-0185.dcm

# %%
filename = file_names[141]
dataset = pydicom.dcmread(filename)

print("Filename.........:", filename)
print("Storage type.....:", dataset.SOPClassUID)

pat_name = dataset.PatientName
display_name = pat_name.family_name + ", " + pat_name.given_name
print("Patient's name...:", display_name)
print("Patient id.......:", dataset.PatientID)
print("Modality.........:", dataset.Modality)
print("Study Date.......:", dataset.StudyDate)

if 'PixelData' in dataset:
    rows = int(dataset.Rows)
    cols = int(dataset.Columns)
    print("Image size.......: {rows:d} x {cols:d}, {size:d} bytes".format(
        rows=rows, cols=cols, size=len(dataset.PixelData)))
    if 'PixelSpacing' in dataset:
        print("Pixel spacing....:", dataset.PixelSpacing)

# use .get() if not sure the item exists, and want a default value if missing
print("Slice location...:", dataset.get('SliceLocation', "(missing)"))

# plot the image using matplotlib
plt.imshow(dataset.pixel_array, cmap=plt.cm.bone)
plt.show()
# Out:
# Filename.........: ./alignment_images/IM-0002-0142.dcm
# Storage type.....: 1.2.840.10008.5.1.4.1.1.2
# Patient's name...: ROBOT POSITION MARKER,
# Patient id.......: 0000200
# Modality.........: CT
# Study Date.......: 20190425
# Image size.......: 512 x 512, 524288 bytes
# Pixel spacing....: ['0.582031', '0.582031']
# Slice location...: 26.0755

# %%
image_stack = np.empty([len(file_names), dataset.pixel_array.shape[0], dataset.pixel_array.shape[1]])
voxel_locations = np.empty(image_stack.shape)
datasets = []

for i, filename  in enumerate(file_names):
    dataset = pydicom.dcmread(filename)
    datasets.append(dataset)
    image_stack[i, :,:] = dataset.pixel_array

# %%
print("Slice location...:", datasets[150].get('SliceLocation', "(missing)"))
print("Slice location...:", datasets[151].get('SliceLocation', "(missing)"))
# Out:
# Slice location...: 31.7005
# Slice location...: 32.3255

# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt

plt.subplot(1,2,1)
plt.hist(image_stack.ravel(),256,[0,1250])
plt.subplot(1,2,2)
plt.imshow(image_stack[141,:,:], cmap=plt.cm.bone)
plt.savefig('subplotted', bbox_inches='tight')

plt.show()

# %%
 (datasets[1].get('SliceLocation', "(missing)") - datasets[0].get('SliceLocation', "(missing)"))
# Out:
# -0.625

# %%
slices, rows, cols = np.where(image_stack > 2000)

img_example = np.zeros([512,512])
img_example[rows[np.where(slices==141)],cols[np.where(slices==141)]] = 1
plt.imshow(img_example)

slices = slices * (datasets[1].get('SliceLocation', "(missing)") - datasets[0].get('SliceLocation', "(missing)"))
rows = rows * dataset.PixelSpacing[0]
cols = cols * dataset.PixelSpacing[1]

# %%
from mpl_toolkits.mplot3d import Axes3D
# %matplotlib notebook

from scipy.cluster.vq import kmeans,vq

data = np.vstack([slices, rows, cols]).astype(float).T
centroids,_ = kmeans(data,6)
idx,_ = vq(data,centroids)

fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

for i in range(6):
    ax.scatter(data[idx==i,0], data[idx==i,1], data[idx==i,2])

ax.set_xlabel('X Label')
ax.set_ylabel('Y Label')
ax.set_zlabel('Z Label')

plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
np.save('centroids.npy', centroids)
